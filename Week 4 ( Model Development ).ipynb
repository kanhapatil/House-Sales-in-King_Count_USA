# %% [markdown]
# # Linear Regression and Multiple Linear Regression
# - **Linear regression will refer to one independent variable to make a prediction**
# - **Multiple Linear regression will refer to multiple independent variable to make a prediction**
#
# ## Simple Linear Regression
# - 1) The predictor (independent) variable - x
# - 2) The target (dependent) variable - y
# **y = b0 + b1x**
#
# **Where : b0 = intercept & b1 = slope**
#
# ## Estimated linear model
# - **We can view the intercept (b0)**
#     - **Code Example : lm.intercept_**
#
#
# - **We can also view the slope (b1)**
#     - **Code Example : lm.coef_**
#
# ## Multiple Linear Regression
# - **This method is used to explain the relationship between:**
#     - One continuous target (Y) variable
#     - Two or more predictor (X) variables
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# # Questions:
# - 1) Considered the following equation:
# ![image-3.png](attachment:image-3.png)
# - the variable y is
# - **Ans : the target or dependent variable**

# %% [markdown]
# # Model Evaluation using Visualization
# ## Why use regression plot?
# - **It gives us a good estimate of:**
# - 1) The relationship between two variable
# - 2) The strength of the correlation
# - 3) The direction of the relationship (positive or negative)
#
#
# - **Regression plot shows us a combination of:**
# - The scatter plot : where each point represents a different y
# - The fitted linear regression line (y^)
#
#
# - **How to plot**
# - import seaborn as sns
# - sns.regplot(x="independent_variable", y="target_variable", data=df)
#
# - **Residual plot**
# - sns.residplot(x="independent_variable", y="target_variable", data=df)

# %% [markdown]
# # Polynomial Regressions
# - **A special case of the general linear regression model**
# - **Useful for describing curvilinear relationships**
#
# ## Curvilinear relationship:
# - **By squaring or setting higher-order terms of the predictor variables**
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
