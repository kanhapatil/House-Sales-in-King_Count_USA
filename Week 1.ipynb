# %% [markdown]
# # Why Data Analysis
# - Data is everywhere
# - Data analysis/data science help us answer question from data
# - Data analysis plays an important role in:
#     - Discovering useful information
#     - Answering questions
#     - Predicting future or unkown

# %% [markdown]
# # Python Packages for Data Science
# - **1) Scientific computing libraries**
#     - Pandas ( Data structure and tools )
#     - Numpy ( Arrays & matrices )
#     - Scipy ( Integrals , solving differential equations, optimization )
#
#
# - **2) Visualization libraries**
#     - Matplotlib ( Plots & Graphs )
#     - Seaborn ( Plots : heat map, time series, violin plots )
#
#
# - **3) Algorithmic libraries**
#     - Scikit-Learn ( Regression, Classification )
#     - Statsmodel ( Explore data, estimate statistical models, and perform statistical tests )
#
#
# ### Question 1
# - **What description best describes the library Pandas?**
#
# - **Ans :** Offers data structure and tools for effective data manipulation and analysis. It provides fast access to structured data. The primary instrument of Pandas is a two-dimensional table consisting of columns and rows labels which are called a DataFrame. It is designed to provide an  easy indexing function.

# %% [markdown]
# # Importing and Exporting Data in Python
# ## Importing Data
# - **Process of loading and reading data into python from various resources**
#
# - **Two important properties**
#     - 1) Format
#         - Various formats : .csv, .json, xlsx
#
#
#     - 2) File path of dataset
#         - Computer : C/kanha/users/data.csv
#         - Internet : https://xyz/data.csv
#
# ### Importing CSV into Python
# - import pandas as pd
# - df = pd.read_csv("data.csv")
#
# ### Importing CSV without header
# - df = pd.read_csv("data.csv", header=None)

# %% [markdown]
# # Getting Started Analyzing Data in Python
# ## Basic insights from the data
# - **Understand your data before you begin any analysis**
#
# - **Should check**
#     - Data types
#     - Data distribution
#
# - **Locate potential issues with the data**
#
# ### Questions 1:
# - **how would you generate descriptive statistics for all the columns for the dataframe df**
# - **Ans :** df.describe(include = "all")

# %% [markdown]
# # Accessing Databases with Python
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ## Concepts of the Python DB API
# - **Connection objects**
#     - Database connections
#     - Manage transactions
#
# - **Cursor objects**
#     - Database queries
#
# ### What are the connections methods
# - cursor()
# - commit()
# - rollback()
# - close()
#
# ![image-3.png](attachment:image-3.png)
